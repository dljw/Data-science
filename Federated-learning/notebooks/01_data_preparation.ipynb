# %%
import pandas as pd
import os

from sklearn.model_selection import TimeSeriesSplit

# %%
df = pd.read_csv("../data/raw/clean_data.csv")

# %%
df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1  2010-02-05      24924.50      False        42.31       2.572
# 1      1     2  2010-02-05      50605.27      False        42.31       2.572
# 2      1     3  2010-02-05      13740.12      False        42.31       2.572
# 3      1     4  2010-02-05      39954.04      False        42.31       2.572
# 4      1     5  2010-02-05      32229.38      False        42.31       2.572
#
#    MarkDown1  MarkDown2  MarkDown3  ...  Unemployment  Type    Size  \
# 0        0.0        0.0        0.0  ...         8.106     A  151315
# 1        0.0        0.0        0.0  ...         8.106     A  151315
# 2        0.0        0.0        0.0  ...         8.106     A  151315
# 3        0.0        0.0        0.0  ...         8.106     A  151315
# 4        0.0        0.0        0.0  ...         8.106     A  151315
#
#    Super_Bowl Labor_Day  Thanksgiving  Christmas  week  month  year
# ...

# %%
# Splitting data into Stores
store_dir = "../data/store_level_data/"

for store in df['Store'].unique():
    df_sub = df[df['Store'] == store]
    df_sub['Date'] = pd.to_datetime(df_sub['Date'])
    df_sub = df_sub.set_index("Date")
    path = os.path.join(store_dir,"store_" + str(store))
    os.makedirs(path)
    train = df_sub.loc['2012-06-01':].reset_index()
    valid = df_sub.loc['2012-06-02':'2012-10-01'].reset_index()
    test = df_sub.loc['2012-10-01':].reset_index()
    train.to_csv(os.path.join(path, "train.csv"), index=False)
    valid.to_csv(os.path.join(path, "valid.csv"), index=False)
    test.to_csv(os.path.join(path, "test.csv"), index=False)
# Out:
# /var/folders/1q/26x3nv656dg2gv4xzbytws5m0000gn/T/ipykernel_4364/3023500077.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['Date'] = pd.to_datetime(df_sub['Date'])
# /var/folders/1q/26x3nv656dg2gv4xzbytws5m0000gn/T/ipykernel_4364/3023500077.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['Date'] = pd.to_datetime(df_sub['Date'])
# /var/folders/1q/26x3nv656dg2gv4xzbytws5m0000gn/T/ipykernel_4364/3023500077.py:6: SettingWithCopyWarning:
# ...

# %%
df_sub = df[df['Store'] == 1]
df_sub['Date'] = pd.to_datetime(df_sub['Date'])
df_sub = df_sub.set_index("Date")
# Out:
# /var/folders/1q/26x3nv656dg2gv4xzbytws5m0000gn/T/ipykernel_4364/1584948984.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['Date'] = pd.to_datetime(df_sub['Date'])

# %%
df_sub.loc['2012-06-01':].shape, df_sub.loc['2012-06-02':'2012-10-01'].shape, df_sub.loc['2012-10-01':].shape
# Out:
# ((1573, 22), (1214, 22), (288, 22))

# %%
df_sub.loc['2012-10-30':]
# Out:
# Empty DataFrame
# Columns: [Store, Dept, Weekly_Sales, IsHoliday, Temperature, Fuel_Price, MarkDown1, MarkDown2, MarkDown3, MarkDown4, MarkDown5, CPI, Unemployment, Type, Size, Super_Bowl, Labor_Day, Thanksgiving, Christmas, week, month, year]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_sub_1 = df_sub.loc['2012-10-01':]
df_sub_1[df_sub_1['Dept'] == 1]
# Out:
#             Store  Dept  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# Date
# 2012-10-05      1     1      21904.47      False        68.55       3.617
# 2012-10-12      1     1      22764.01      False        62.99       3.601
# 2012-10-19      1     1      24185.27      False        67.97       3.594
# 2012-10-26      1     1      27390.81      False        69.16       3.506
#
#             MarkDown1  MarkDown2  MarkDown3  MarkDown4  ...  Unemployment  \
# Date                                                    ...
# 2012-10-05    8077.89       0.00      18.22    3617.43  ...         6.573
# 2012-10-12    2086.18       0.00       8.11     602.36  ...         6.573
# 2012-10-19     950.33       0.00       4.93      80.25  ...         6.573
# 2012-10-26    2585.85      31.75       6.00    1057.16  ...         6.573
#
#             Type    Size Super_Bowl  Labor_Day  Thanksgiving  Christmas  week  \
# Date
# ...
